# %% [markdown]
# # Practical work 8: Split and Merge
#
# In this practical work, we implement and test the split and merge algorithm.

# %%
### Usefull libraries
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

### Data
img_test = np.full((64,64),150,dtype=np.uint8)
img_test[32:48,16:16+32] = 100
img_test[8:24,40:56] = 50
angio = np.array(Image.open('img/angiogra.png'))
cam = np.array(Image.open('img/cameraman.png'))
muscle = np.array(Image.open('img/muscle.png'))
prisme = np.array(Image.open('img/prisme.png'))
seiche = np.array(Image.open('img/seiche.png'))

### Usefull functions
def neighbors(b,K):
    """ blockStat*list[blockStat]->list[blockStat]
        returns the list of neighbors of b and elements of K 
    """
    def belongsTo(x,y,a):
        """ int*int*BlockStat -> bool 
            Test if pixel (x,y) belongs to block a 
        """
        return x>=a[0] and y>=a[1] and x<a[0]+a[2] and y<a[1]+a[3]
    def areNeighbors(a,b):
        """ BlockStat**2 -> bool
            Test if a and b are neighbors
        """
        if a[2]>b[2] and a[3]>b[3]:
            a,b=b,a
        x,y = a[0]+a[2]//2,a[1]+a[3]//2
        return belongsTo(x+a[2],y,b) or belongsTo(x-a[2],y,b) or belongsTo(x,y+a[3],b) or belongsTo(x,y-a[3],b)
    N = []
    for n in K:
        if areNeighbors(b,n):
            N.append(n)
    return N

# %% [markdown]
# ## Exercise 1
#
# ### Question 1
# Write the recursive function ``split()`` discussed in tutorial work.
# It takes as input the image, a region, a predicate, and a variable number of arguments.
# The region is a Python formal type ``Block`` defined by:
# ```python
# type Block = tuple[int**4]
# ```
# The function ``split()`` returns a quadtree, a Python formal type, recursivelly defined by:
# ```python
# type QuadTree = list[(QuadTree**4|Block)]
# ```
#
# The predicate is a Python function with the following signature:
# ```python
# Array*Block*...->bool
# ```
# It can take a variable number of parameters which correspond to the parameters required by the predicate.

# %%
# type Block = tuple[int**4]
# type QuadTree = list[(QuadTree**4|Block)] 

def NO(R):
    return (R[0],R[1],int(R[2]/2),int(R[3]/2))
def NE(R):
    return (R[0],R[1]+int(R[3]/2),int(R[2]/2),int(R[3]/2))
def SO(R):
    return (R[0]+int(R[2]/2),R[1],int(R[2]/2),int(R[3]/2))
def SE(R):
    return (R[0]+int(R[2]/2),R[1]+int(R[3]/2),int(R[2]/2),int(R[3]/2))

def split(I,reg,pred,*args):
    """ Array*Block*(Array*Block*...->bool)*... -> 4-aire
        Performs a quadtree splitting of image I drived by a predicate
    """
    if pred(I,reg,args[0]):
        return [split(I,NO(reg),pred,args[0]),
               split(I,NE(reg),pred,args[0]),
               split(I,SO(reg),pred,args[0]),
               split(I,SE(reg),pred,args[0]),reg]
    return [reg]

# %% [markdown]
# ### Question 2
# Write the function ```predsplit(I,B,*args)``` with signature:
# ```python
# Array*Block*... -> bool
# ```
# that returns True if the standard deviation of image ``I`` computed in region ``B`` is greater than the first value of argument ``*args`` (it can be accessed simply by ``*args[0]``).

# %%
def predsplit(I,reg,*args):
    """ Array*Block*... -> bool
    """ 
    x,y,n,m = reg
    R = I[x:x+n+1,y:y+m+1]
    # on ne peut pas diviser s'il y a moins de 4pixels
    if (n<2) and (m<2):
        return False
    if np.std(R) > args[0]:
        return True
    return False

# %% [markdown]
# ### Question 3
# Write the function ``listRegions()`` which applies a depth-first search on the quadtree given as parameter, and returns the list of the leaves of the quadtree.
#
# Some recalls about lists in Python;
#  - Initialization: `L = []` (empty list)
#  - Add a element `a` into a list `L`: `L.append(a)`

# %%
def listRegions(Qt):
    """ QuadTree -> list[Block]
    """
    if len(Qt) > 1:
        # on concatene les feuilles des regions NO,NE,SO et SE
        return listRegions(Qt[0])+listRegions(Qt[1])+listRegions(Qt[2])+listRegions(Qt[3])
            
    return list(Qt) # liste avec un seul element

# %% [markdown]
# ### Question 4
# Test your codes on the synthetic image ``img_test`` seen in tutorial work. Print the value returned by ``split()`` as well as the one returned by ``listRegions()``.

# %%
img_test = np.zeros((64,64))

# ajout des 150
x,y = 8,8*5
for i in range(16):
  for j in range(16):
    img_test[x+i,y+j] = 150
# ajout des 100
x,y = 8*4,8*2
for i in range(16):
  for j in range(4*8):
    img_test[x+i,y+j] = 100

plt.imshow(img_test)

# %%
K = split(img_test,(0,0,img_test.shape[0],img_test.shape[1]),predsplit,0)
# print(K)

# %%
L = listRegions(K)
print(L)
# Out:
# [(0, 0, 16, 16), (0, 16, 16, 16), (16, 0, 8, 8), (16, 8, 8, 8), (24, 0, 8, 8), (24, 8, 4, 4), (24, 12, 4, 4), (28, 8, 4, 4), (28, 12, 2, 2), (28, 14, 2, 2), (30, 12, 2, 2), (30, 14, 1, 1), (30, 15, 1, 1), (31, 14, 1, 1), (31, 15, 1, 1), (16, 16, 8, 8), (16, 24, 8, 8), (24, 16, 4, 4), (24, 20, 4, 4), (28, 16, 2, 2), (28, 18, 2, 2), (30, 16, 1, 1), (30, 17, 1, 1), (31, 16, 1, 1), (31, 17, 1, 1), (30, 18, 1, 1), (30, 19, 1, 1), (31, 18, 1, 1), (31, 19, 1, 1), (28, 20, 2, 2), (28, 22, 2, 2), (30, 20, 1, 1), (30, 21, 1, 1), (31, 20, 1, 1), (31, 21, 1, 1), (30, 22, 1, 1), (30, 23, 1, 1), (31, 22, 1, 1), (31, 23, 1, 1), (24, 24, 4, 4), (24, 28, 4, 4), (28, 24, 2, 2), (28, 26, 2, 2), (30, 24, 1, 1), (30, 25, 1, 1), (31, 24, 1, 1), (31, 25, 1, 1), (30, 26, 1, 1), (30, 27, 1, 1), (31, 26, 1, 1), (31, 27, 1, 1), (28, 28, 2, 2), (28, 30, 2, 2), (30, 28, 1, 1), (30, 29, 1, 1), (31, 28, 1, 1), (31, 29, 1, 1), (30, 30, 1, 1), (30, 31, 1, 1), (31, 30, 1, 1), (31, 31, 1, 1), (0, 32, 4, 4), (0, 36, 4, 4), (4, 32, 4, 4), (4, 36, 2, 2), (4, 38, 2, 2), (6, 36, 2, 2), (6, 38, 1, 1), (6, 39, 1, 1), (7, 38, 1, 1), (7, 39, 1, 1), (0, 40, 4, 4), (0, 44, 4, 4), (4, 40, 2, 2), (4, 42, 2, 2), (6, 40, 1, 1), (6, 41, 1, 1), (7, 40, 1, 1), (7, 41, 1, 1), (6, 42, 1, 1), (6, 43, 1, 1), (7, 42, 1,
2, 2), (28, 34, 2, 2), (30, 32, 1, 1), (30, 33, 1, 1), (31, 32, 1, 1), (31, 33, 1, 1), (30, 34, 1, 1), (30, 35, 1, 1), (31, 34, 1, 1), (31, 35, 1, 1), (28, 36, 2, 2), (28, 38, 2, 2), (30, 36, 1, 1), (30, 37, 1, 1), (31, 36, 1, 1), (31, 37, 1, 1), (30, 38, 1, 1), (30, 39, 1, 1), (31, 38, 1, 1), (31, 39, 1, 1), (24, 40, 4, 4), (24, 44, 4, 4), (28, 40, 2, 2), (28, 42, 2, 2), (30, 40, 1, 1), (30, 41, 1, 1), (31, 40, 1, 1), (31, 41, 1, 1), (30, 42, 1, 1), (30, 43, 1, 1), (31, 42, 1, 1), (31, 43, 1, 1), (28, 44, 2, 2), (28, 46, 2, 2), (30, 44, 1, 1), (30, 45, 1, 1), (31, 44, 1, 1), (31, 45, 1, 1), (30, 46, 1, 1), (30, 47, 1, 1), (31, 46, 1, 1), (31, 47, 1, 1), (16, 48, 4, 4), (16, 52, 2, 2), (16, 54, 1, 1), (16, 55, 1, 1), (17, 54, ...

# %% [markdown]
# ### Question 5
# Write the function ```drawRegions(L,I)``` which takes as arguments a list of regions, an image, and returns an image  where the boundaries of each region have been traced with red color. Indication: the returned image is a hypermatrix of dimension 3, the third dimension is of size 3 and encodes the red, green and blue components of a RGB colorspace. Test the function on the previous example.

# %%
def drawRegions(L,I):
    """ list[Block]*Array -> Array
        parcours de la liste dessin des régions 
    """
    B = np.zeros((I.shape[0],I.shape[1],3))
    for reg in L:
        x,y,n,m = reg
        # bordure de gauche et de droit
        for i in range(n):
            B[x+i,y,0] = 255  # RGB, le R à full
            B[x+i,y+m-1,0] = 255 
        # bordure du haut et du bas
        for j in range(m):
            B[x,y+j,0] = 255  
            B[x+n-1,y+j,0] = 255 
    
    return B

# %%
plt.imshow(drawRegions(L,img_test))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ### Question 6
# Add a Gaussian noise with standard deviation 5 to the image ``img_test``.
# Apply the quadtree splitting on the noisy image by adjusting the threshold to obtain the same result as in the previous question.
# Which threshold value should be chosen? Does this make sense to you?
#
# Hint: use the Numpy function ``random.randn()`` which generates random values according to a normal distribution (Gaussian distribution of null mean and variance 1). To obtain realizations of a Gaussian distribution of standard deviation $\sigma$, it is sufficient to multiply by $\sigma$ the realizations of a normal distribution.

# %%
np.random.seed(92)  # pour eviter des random differents à chaque execution
img_test_noise = np.copy(img_test)
sig = np.std(img_test.reshape(img_test.size))
for i in range(img_test_noise.shape[0]):
  for j in range(img_test_noise.shape[1]):
    img_test_noise[i,j] += np.random.randn()*sig

Kn = split(img_test_noise,(0,0,img_test_noise.shape[0],img_test_noise.shape[1]),predsplit,1.04*sig)
Ln = listRegions(Kn)
plt.imshow(drawRegions(Ln,img_test_noise))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Exercise 2
#
# Experiment the split algorithm on the 4 natural images provided. For each image try to find the threshold that seems to you visually the best. Display the number of regions obtained after splitting.

# %%
I = angio
sig = np.std(I.reshape(I.size))
K = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.2*sig)
L = listRegions(K)
plt.imshow(I)
plt.show()
plt.imshow(drawRegions(L,I))
plt.show()

K = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.4*sig)
L = listRegions(K)
plt.imshow(drawRegions(L,I))
plt.show()

K = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.6*sig)
L = listRegions(K)
plt.imshow(drawRegions(L,I))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
I = cam
sig = np.std(I.reshape(I.size))
K = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.1*sig)
L = listRegions(K)
plt.imshow(I)
plt.show()
plt.imshow(drawRegions(L,I))
plt.show()

K = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.4*sig)
L = listRegions(K)
plt.imshow(drawRegions(L,I))
plt.show()

K = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.6*sig)
L = listRegions(K)
plt.imshow(drawRegions(L,I))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
I = muscle
sig = np.std(I.reshape(I.size))
K = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.2*sig)
L = listRegions(K)
plt.imshow(I)
plt.show()
plt.imshow(drawRegions(L,I))
plt.show()

K = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.2*sig)
L = listRegions(K)
plt.imshow(drawRegions(L,I))
plt.show()

K = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.4*sig)
L = listRegions(K)
plt.imshow(drawRegions(L,I))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
I = prisme
sig = np.std(I.reshape(I.size))
K = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.1*sig)
L = listRegions(K)
plt.imshow(I)
plt.show()
plt.imshow(drawRegions(L,I))
plt.show()

K = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.4*sig)
L = listRegions(K)
plt.imshow(drawRegions(L,I))
plt.show()

K = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.6*sig)
L = listRegions(K)
plt.imshow(drawRegions(L,I))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
I = seiche
sig = np.std(I.reshape(I.size))
K = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.1*sig)
L = listRegions(K)
plt.imshow(I)
plt.show()
plt.imshow(drawRegions(L,I))
plt.show()

K = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.4*sig)
L = listRegions(K)
plt.imshow(drawRegions(L,I))
plt.show()

K = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.6*sig)
L = listRegions(K)
plt.imshow(drawRegions(L,I))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Selon la valeur de seuillage on cadre plus de régions ou pas. Plus elle augmente moins on a de régions, mais elles sont quand même beaucoup plus large quand la valeur de seuillage est petite, du coup beaucoup moins précise.

# %% [markdown]
# ## Exercise 3
# ### Question 1
# Modify the function ``listRegions(L)`` to make it a function ``listRegionsStat(L,I)`` which computes the list of leaves of the quadtree ``L``. Each element of this list will be enriched with three scalar values: the first being the size, the second the mean and the third the variance of pixel values of the block in the image ``I``. This function then returns a list whose elements have the following formal type:
# ```python
# type BlockStat = tuple[int**4,int,float**2]
# ```
#
# The first four values are those of the ``Block`` type, the fifth is the size of the block (in number of pixels) and the last two values are the mean and variance calculated over the region.

# %%
# type BlockStat = tuple[int**4,int,float**2]

def listRegionsStat(Qt,I):
    """ QuadTree*Array -> list[BlockStat] """
    if len(Qt) > 1:
        # on concatene les feuilles des regions NO,NE,SO et SE
        return listRegionsStat(Qt[0],I)+listRegionsStat(Qt[1],I)+listRegionsStat(Qt[2],I)+listRegionsStat(Qt[3],I)
    
    x,y,n,m = Qt[0]
    R = I[x:x+n,y:y+m]
    return [(x,y,n,m,n*m,np.mean(R),np.var(R))] # liste avec un seul element

# %%
listRegionsStat(K,I)
# Out:
# [(0, 0, 16, 16, 256, 46.5703125, 104.17474365234375),
#  (0, 16, 8, 8, 64, 59.421875, 2.806396484375),
#  (0, 24, 4, 4, 16, 57.6875, 5.33984375),
#  (0, 28, 1, 1, 1, 56.0, 0.0),
#  (0, 29, 1, 1, 1, 65.0, 0.0),
#  (1, 28, 1, 1, 1, 55.0, 0.0),
#  (1, 29, 1, 1, 1, 67.0, 0.0),
#  (0, 30, 2, 2, 4, 96.25, 63.6875),
#  (2, 28, 1, 1, 1, 58.0, 0.0),
#  (2, 29, 1, 1, 1, 70.0, 0.0),
#  (3, 28, 1, 1, 1, 59.0, 0.0),
#  (3, 29, 1, 1, 1, 71.0, 0.0),
#  (2, 30, 2, 2, 4, 98.75, 39.6875),
#  (4, 24, 4, 4, 16, 58.4375, 4.87109375),
#  (4, 28, 2, 2, 4, 71.25, 70.6875),
#  (4, 30, 2, 2, 4, 95.75, 6.6875),
#  (6, 28, 2, 2, 4, 83.75, 82.1875),
#  (6, 30, 1, 1, 1, 98.0, 0.0),
#  (6, 31, 1, 1, 1, 90.0, 0.0),
#  (7, 30, 1, 1, 1, 103.0, 0.0),
#  (7, 31, 1, 1, 1, 91.0, 0.0),
#  (8, 16, 8, 8, 64, 68.796875, 36.943115234375),
#  (8, 24, 4, 4, 16, 63.3125, 15.58984375),
#  (8, 28, 2, 2, 4, 96.25, 87.1875),
#  (8, 30, 1, 1, 1, 106.0, 0.0),
#  (8, 31, 1, 1, 1, 90.0, 0.0),
#  (9, 30, 1, 1, 1, 107.0, 0.0),
#  (9, 31, 1, 1, 1, 86.0, 0.0),
#  (10, 28, 2, 2, 4, 95.0, 50.0),
#  (10, 30, 1, 1, 1, 101.0, 0.0),
#  (10, 31, 1, 1, 1, 80.0, 0.0),
#  (11, 30, 1, 1, 1, 93.0, 0.0),
#  (11, 31, 1, 1, 1, 75.0, 0.0),
#  (12, 24, 2, 2, 4, 66.0, 6.5),
#  (12, 26, 2, 2, 4, 77.0, 45.0),
#  (14, 24, 2, 2, 4, 72.25, 8.1875),
#  (14, 26, 1, 1, 1, 77.0, 0.0),
#  (14, 27, 1, 1, 1, 94.0, 0.0),
#  (15, 26, 1, 1, 1, 82.0, 0.0),
#  (15, 27, 1, 1, 1, 99.0, 0.0),
#  (12, 28, 2, 2, 4, 99.0, 0.5),
#  (12, 30, 2, 2, 4, 75.75, 90.6875),
#  (14, 28, 2, 2, 4, 108.5, 8.25),
#  (14, 30, 2, 2, 4, 73.75, 115.6875),
#  (16, 0, 8, 8, 64, 37.859375, 17.777099609375),
#  (16, 8, 8, 8, 64, 58.015625, 40.859130859375),
#  (24, 0, 8, 8, 64, 42.359375, 42.386474609375),
#  (24, 8, 8, 8, 64, 65.125, 54.421875),
#  (16, 16, 8, 8, 64, 75.0, 7.09375),
#  (16, 24, 2, 2, 4, 75.5, 2.75),
#  (16, 26, 2, 2, 4, 95.75, 81.6875),
#  (18, 24, 2, 2, 4, 78.25, 15.6875),
#  (18, 26, 2, 2, 4, 103.75, 67.6875),
#  (16, 28, 1, 1, 1, 117.0, 0.0),
#  (16, 29, 1, 1, 1, 110.0, 0.0),
#  (17, 28, 1, 1, 1, 116.0, 0.0),
#  (17, 29, 1, 1, 1, 107.0, 0.0),
#  (16, 30, 2, 2, 4, 75.0, 110.5),
#  (18, 28, 1, 1, 1, 114.0, 0.0),
#  (18, 29, 1, 1, 1, 101.0, 0.0),
#  (19, 28, 1, 1, 1, 114.0, 0.0),
#  (19, 29, 1, 1, 1, 100.0, 0.0),
#  (18, 30, 2, 2, 4, 70.0, 72.5),
#  (20, 24, 2, 2, 4, 89.75, 47.1875),
#  (20, 26, 2, 2, 4, 111.75, 13.6875),
#  (22, 24, 2, 2, 4, 101.75, 103.6875),
#  (22, 26, 1, 1, 1, 121.0, 0.0),
#  (22, 27, 1, 1, 1, 116.0, 0.0),
#  (23, 26, 1, 1, 1, 127.0, 0.0),
#  (23, 27, 1, 1, 1, 111.0, 0.0),
#  (20, 28, 1, 1, 1, 109.0, 0.0),
#  (20, 29, 1, 1, 1, 89.0, 0.0),
#  (21, 28, 1, 1, 1, 102.0, 0.0),
#  (21, 29, 1, 1, 1, 81.0, 0.0),
#  (20, 30, 2, 2, 4, 61.25, 31.1875),
#  (22, 28, 1, 1, 1, 98.0, 0.0),
#  (22, 29, 1, 1, 1, 78.0, 0.0),
#  (23, 28, 1, 1, 1, 87.0, 0.0),
#  (23, 29, 1, 1, 1, 69.0, 0.0),
#  (22, 30, 2, 2, 4, 58.0, 7.5),
#  (24, 16, 4, 4, 16, 77.25, 4.4375),
#  (24, 20, 2, 2, 4, 80.75, 0.6875),
#  (24, 22, 2, 2, 4, 93.0, 36.5),
#  (26, 20, 2, 2, 4, 85.0, 14.5),
#  (26, 22, 2, 2, 4, 106.5, 55.25),
#  (28, 16, 4, 4, 16, 82.3125, 17.96484375),
#  (28, 20, 2, 2, 4, 97.75, 53.1875),
#  (28, 22, 2, 2, 4, 119.5, 15.25),
#  (30, 20, 2, 2, 4, 112.5, 61.25),
#  (30, 22, 1, 1, 1, 124.0, 0.0),
#  (30, 23, 1, 1, 1, 116.0, 0.0),
#  (31, 22, 1, 1, 1, 125.0, 0.0),
#  (31, 23, 0, 0, 0, nan, nan),
#  (31, 23, 0, 0, 0, nan, nan),
#  (31, 23, 0, 0, 0, nan, nan),
#  (31, 23, 0, 0, 0, nan, nan),
#  (24, 24, 2, 2, 4, 117.25, 33.1875),
#  (24, 26, 1, 1, 1, 122.0, 0.0),
#  (24, 27, 1, 1, 1, 104.0, 0.0),
#  (25, 26, 1, 1, 1, 115.0, 0.0),
#  (25, 27, 1, 1, 1, 94.0, 0.0),
#  (26, 24, 1, 1, 1, 122.0, 0.0),
#  (26, 25, 1, 1, 1, 120.0, 0.0),
#  (27, 24, 1, 1, 1, 122.0, 0.0),
#  (27, 25, 0, 0, 0, nan, nan),
#  (27, 25, 0, 0, 0, nan, nan),
#  (27, 25, 0, 0, 0, nan, nan),
#  (27, 25, 0, 0, 0, nan, nan),
#  (26, 26, 1, 1, 1, 103.0, 0.0),
#  (26, 27, 1, 1, 1, 82.0, 0.0),
#  (27, 26, 1, 1, 1, 94.0, 0.0),
#  (27, 27, 1, 1, 1, 73.0, 0.0),
#  (24, 28, 4, 4, 16, 57.5, 68.0),
#  (28, 24, 1, 1, 1, 116.0, 0.0),
#  (28, 25, 1, 1, 1, 99.0, 0.0),
#  (29, 24, 0, 0, 0, nan, nan),
#  (29, 24, 0, 0, 0, nan, nan),
#  (29, 24, 0, 0, 0, nan, nan),
#  (29, 24, 0, 0, 0, nan, nan),
#  (29, 25, 1, 1, 1, 86.0, 0.0),
#  (28, 26, 2, 2, 4, 64.75, 65.1875),
#  (30, 24, 1, 1, 1, 97.0, 0.0),
#  (30, 25, 1, 1, 1, 75.0, 0.0),
#  (31, 24, 1, 1, 1, 83.0, 0.0),
#  (31, 25, 1, 1, 1, 63.0, 0.0),
#  (30, 26, 2, 2, 4, 52.5, 18.25),
#  (28, 28, 4, 4, 16, 48.6875, 2.83984375),
#  (0, 32, 16, 16, 256, 52.3984375, 64.03656005859375),
#  (0, 48, 16, 16, 256, 62.2578125, 81.41009521484375),
#  (16, 32, 16, 16, 256, 54.52734375, 27.522689819335938),
#  (16, 48, 8, 8, 64, 61.515625, 8.343505859375),
#  (35, 17, 1, 1, 1, 97.0, 0.0),
#  (34, 18, 2, 2, 4, 117.75, 91.1875),
#  (32, 20, 2, 2, 4, 124.5, 25.25),
#  (32, 22, 1, 1, 1, 122.0, 0.0),
#  (32, 23, 1, 1, 1, 100.0, 0.0),
#  (33, 22, 0, 0, 0, nan, nan),
#  (33, 22, 0, 0, 0, nan, nan),
#  (33, 22, 0, 0, 0, nan, nan),
#  (33, 22, 0, 0, 0, nan, nan),
#  (33, 23, 1, 1, 1, 91.0, 0.0),
#  (34, 20, 1, 1, 1, 128.0, 0.0),
#  (34, 21, 1, 1, 1, 124.0, 0.0),
#  (35, 20, 1, 1, 1, 133.0, 0.0),
#  (35, 21, 0, 0, 0, nan, nan),
#  (35, 21, 0, 0, 0, nan, nan),
#  (35, 21, 0, 0, 0, nan, nan),
#  (35, 21, 0, 0, 0, nan, nan),
#  (34, 22, 0, 0, 0, nan, nan),
#  (34, 22, 0, 0, 0, nan, nan),
#  (34, 22, 0, 0, 0, nan, nan),
#  (34, 22, 0, 0, 0, nan, nan),
#  (34, 23, 1, 1, 1, 79.0, 0.0),
#  (35, 22, 1, 1, 1, 93.0, 0.0),
#  (35, 23, 1, 1, 1, 69.0, 0.0),
#  (36, 16, 1, 1, 1, 93.0, 0.0),
#  (36, 17, 1, 1, 1, 107.0, 0.0),
#  (37, 16, 1, 1, 1, 98.0, 0.0),
#  (37, 17, 1, 1, 1, 116.0, 0.0),
#  (36, 18, 2, 2, 4, 134.25, 32.1875),
#  (38, 16, 2, 2, 4, 119.25, 41.6875),
#  (38, 18, 2, 2, 4, 142.25, 7.1875),
#  (36, 20, 1, 1, 1, 133.0, 0.0),
#  (36, 21, 0, 0, 0, nan, nan),
#  (36, 21, 0, 0, 0, nan, nan),
#  (36, 21, 0, 0, 0, nan, nan),
#  (36, 21, 0, 0, 0, nan, nan),
#  (37, 20, 0, 0, 0, nan, nan),
#  (37, 20, 0, 0, 0, nan, nan),
#  (37, 20, 0, 0, 0, nan, nan),
#  (37, 20, 0, 0, 0, nan, nan),
#  (37, 21, 0, 0, 0, nan, nan),
#  (37, 21, 0, 0, 0, nan, nan),
#  (37, 21, 0, 0, 0, nan, nan),
#  (37, 21, 0, 0, 0, nan, nan),
#  (36, 22, 2, 2, 4, 71.5, 98.75),
#  (38, 20, 0, 0, 0, nan, nan),
#  (38, 20, 0, 0, 0, nan, nan),
#  (38, 20, 0, 0, 0, nan, nan),
#  (38, 20, 0, 0, 0, nan, nan),
#  (38, 21, 1, 1, 1, 97.0, 0.0),
#  (39, 20, 0, 0, 0, nan, nan),
#  (39, 20, 0, 0, 0, nan, nan),
#  (39, 20, 0, 0, 0, nan, nan),
#  (39, 20, 0, 0, 0, nan, nan),
#  (39, 21, 1, 1, 1, 91.0, 0.0),
#  (38, 22, 2, 2, 4, 64.0, 51.5),
#  (32, 24, 8, 8, 64, 54.46875, 56.6240234375),
#  (40, 16, 2, 2, 4, 140.25, 73.1875),
#  (62, 24, 0, 0, 0, nan, nan),
#  (62, 25, 1, 1, 1, 63.0, 0.0),
#  (63, 24, 0, 0, 0, nan, nan),
#  (63, 24, 0, 0, 0, nan, nan),
#  (63, 24, 0, 0, 0, nan, nan),
#  (63, 24, 0, 0, 0, nan, nan),
#  (63, 25, 0, 0, 0, nan, nan),
#  (63, 25, 0, 0, 0, nan, nan),
#  (63, 25, 0, 0, 0, nan, nan),
#  (63, 25, 0, 0, 0, nan, nan),
#  (62, 26, 2, 2, 4, 54.0, 19.5),
#  (60, 28, 4, 4, 16, 48.5, 10.25),
#  (32, 32, 8, 8, 64, 53.9375, 28.99609375),
#  (32, 40, 2, 2, 4, 53.5, 2.25),
#  (32, 42, 2, 2, 4, 58.75, 6.1875),
#  (34, 40, 2, 2, 4, 58.75, 13.6875),
#  (34, 42, 1, 1, 1, 64.0, 0.0),
#  (34, 43, 1, 1, 1, 68.0, 0.0),
#  (35, 42, 1, 1, 1, 73.0, 0.0),
#  (35, 43, 1, 1, 1, 83.0, 0.0),
#  (32, 44, 2, 2, 4, 68.25, 6.1875),
#  (32, 46, 2, 2, 4, 71.25, 4.6875),
#  (34, 44, 1, 1, 1, 75.0, 0.0),
#  (34, 45, 1, 1, 1, 80.0, 0.0),
#  (35, 44, 1, 1, 1, 92.0, 0.0),
#  (35, 45, 1, 1, 1, 97.0, 0.0),
#  (34, 46, 2, 2, 4, 86.75, 61.6875),
#  (36, 40, 1, 1, 1, 66.0, 0.0),
#  (36, 41, 0, 0, 0, nan, nan),
#  (36, 41, 0, 0, 0, nan, nan),
#  (36, 41, 0, 0, 0, nan, nan),
#  (36, 41, 0, 0, 0, nan, nan),
#  (37, 40, 0, 0, 0, nan, nan),
#  (37, 40, 0, 0, 0, nan, nan),
#  (37, 40, 0, 0, 0, nan, nan),
#  (37, 40, 0, 0, 0, nan, nan),
#  (37, 41, 1, 1, 1, 99.0, 0.0),
#  (36, 42, 0, 0, 0, nan, nan),
#  (36, 42, 0, 0, 0, nan, nan),
#  (36, 42, 0, 0, 0, nan, nan),
#  (36, 42, 0, 0, 0, nan, nan),
#  (36, 43, 1, 1, 1, 106.0, 0.0),
#  (37, 42, 1, 1, 1, 119.0, 0.0),
#  (37, 43, 1, 1, 1, 130.0, 0.0),
#  (38, 40, 1, 1, 1, 93.0, 0.0),
#  (38, 41, 1, 1, 1, 115.0, 0.0),
#  (39, 40, 1, 1, 1, 105.0, 0.0),
#  (39, 41, 1, 1, 1, 126.0, 0.0),
#  (38, 42, 2, 2, 4, 138.0, 22.5),
#  (36, 44, 4, 4, 16, 123.4375, 97.99609375),
#  (40, 32, 2, 2, 4, 62.75, 0.6875),
#  (40, 34, 2, 2, 4, 69.5, 34.75),
#  (42, 32, 2, 2, 4, 60.75, 3.6875),
#  (42, 34, 1, 1, 1, 72.0, 0.0),
#  (42, 35, 1, 1, 1, 88.0, 0.0),
#  (43, 34, 1, 1, 1, 77.0, 0.0),
#  (43, 35, 1, 1, 1, 100.0, 0.0),
#  (40, 36, 2, 2, 4, 66.75, 29.6875),
#  (40, 38, 2, 2, 4, 78.0, 48.5),
#  (42, 36, 1, 1, 1, 91.0, 0.0),
#  (42, 37, 1, 1, 1, 82.0, 0.0),
#  (43, 36, 1, 1, 1, 113.0, 0.0),
#  (43, 37, 1, 1, 1, 108.0, 0.0),
#  (42, 38, 1, 1, 1, 82.0, 0.0),
#  (42, 39, 1, 1, 1, 87.0, 0.0),
#  (43, 38, 1, 1, 1, 101.0, 0.0),
#  (43, 39, 1, 1, 1, 104.0, 0.0),
#  (44, 32, 1, 1, 1, 60.0, 0.0),
#  (44, 33, 1, 1, 1, 72.0, 0.0),
#  (45, 32, 1, 1, 1, 71.0, 0.0),
#  (45, 33, 1, 1, 1, 85.0, 0.0),
#  (44, 34, 1, 1, 1, 90.0, 0.0),
#  (44, 35, 1, 1, 1, 111.0, 0.0),
#  (45, 34, 1, 1, 1, 102.0, 0.0),
#  (45, 35, 1, 1, 1, 121.0, 0.0),
#  (46, 32, 1, 1, 1, 80.0, 0.0),
#  (46, 33, 1, 1, 1, 102.0, 0.0),
#  (47, 32, 0, 0, 0, nan, nan),
#  (47, 32, 0, 0, 0, nan, nan),
#  (47, 32, 0, 0, 0, nan, nan),
#  (47, 32, 0, 0, 0, nan, nan),
#  (47, 33, 1, 1, 1, 109.0, 0.0),
#  (46, 34, 2, 2, 4, 119.25, 17.1875),
#  (44, 36, 2, 2, 4, 133.25, 13.6875),
#  (44, 38, 2, 2, 4, 127.5, 13.25),
#  (46, 36, 1, 1, 1, 134.0, 0.0),
#  (46, 37, 1, 1, 1, 137.0, 0.0),
#  (47, 36, 1, 1, 1, 118.0, 0.0),
#  (47, 37, 1, 1, 1, 121.0, 0.0),
#  (46, 38, 1, 1, 1, 129.0, 0.0),
#  (46, 39, 1, 1, 1, 117.0, 0.0),
#  (47, 38, 1, 1, 1, 115.0, 0.0),
#  (47, 39, 1, 1, 1, 101.0, 0.0),
#  (40, 40, 1, 1, 1, 104.0, 0.0),
#  (40, 41, 1, 1, 1, 122.0, 0.0),
#  (41, 40, 1, 1, 1, 93.0, 0.0),
#  (41, 41, 1, 1, 1, 102.0, 0.0),
#  (40, 42, 1, 1, 1, 130.0, 0.0),
#  (40, 43, 1, 1, 1, 132.0, 0.0),
#  (41, 42, 1, 1, 1, 110.0, 0.0),
#  (41, 43, 1, 1, 1, 116.0, 0.0),
#  (42, 40, 1, 1, 1, 87.0, 0.0),
#  (42, 41, 1, 1, 1, 82.0, 0.0),
#  (43, 40, 1, 1, 1, 103.0, 0.0),
#  (43, 41, 1, 1, 1, 99.0, 0.0),
#  (42, 42, 2, 2, 4, 95.25, 18.6875),
#  (40, 44, 2, 2, 4, 114.75, 79.1875),
#  (40, 46, 2, 2, 4, 106.75, 56.1875),
#  (42, 44, 2, 2, 4, 96.5, 31.25),
#  (42, 46, 2, 2, 4, 83.75, 15.6875),
#  (44, 40, 2, 2, 4, 127.25, 25.6875),
#  (36, 62, 0, 0, 0, nan, nan),
#  (36, 62, 0, 0, 0, nan, nan),
#  (36, 63, 0, 0, 0, nan, nan),
#  (36, 63, 0, 0, 0, nan, nan),
#  (36, 63, 0, 0, 0, nan, nan),
#  (36, 63, 0, 0, 0, nan, nan),
#  (37, 62, 1, 1, 1, 76.0, 0.0),
#  (37, 63, 0, 0, 0, nan, nan),
#  (37, 63, 0, 0, 0, nan, nan),
#  (37, 63, 0, 0, 0, nan, nan),
#  (37, 63, 0, 0, 0, nan, nan),
#  (38, 60, 1, 1, 1, 69.0, 0.0),
#  (38, 61, 1, 1, 1, 69.0, 0.0),
#  (39, 60, 1, 1, 1, 77.0, 0.0),
#  (39, 61, 0, 0, 0, nan, nan),
#  (39, 61, 0, 0, 0, nan, nan),
#  (39, 61, 0, 0, 0, nan, nan),
#  (39, 61, 0, 0, 0, nan, nan),
#  (38, 62, 0, 0, 0, nan, nan),
#  (38, 62, 0, 0, 0, nan, nan),
#  (38, 62, 0, 0, 0, nan, nan),
#  (38, 62, 0, 0, 0, nan, nan),
#  (38, 63, 0, 0, 0, nan, nan),
#  (38, 63, 0, 0, 0, nan, nan),
#  (38, 63, 0, 0, 0, nan, nan),
#  (38, 63, 0, 0, 0, nan, nan),
#  (39, 62, 0, 0, 0, nan, nan),
#  (39, 62, 0, 0, 0, nan, nan),
#  (39, 62, 0, 0, 0, nan, nan),
#  (39, 62, 0, 0, 0, nan, nan),
#  (39, 63, 1, 1, 1, 124.0, 0.0),
#  (40, 48, 2, 2, 4, 114.25, 20.6875),
#  (40, 50, 2, 2, 4, 126.25, 21.6875),
#  (42, 48, 1, 1, 1, 99.0, 0.0),
#  (42, 49, 1, 1, 1, 116.0, 0.0),
#  (43, 48, 1, 1, 1, 96.0, 0.0),
#  (43, 49, 1, 1, 1, 115.0, 0.0),
#  (42, 50, 2, 2, 4, 134.5, 20.25),
#  (40, 52, 4, 4, 16, 113.8125, 185.02734375),
#  (44, 48, 2, 2, 4, 104.0, 59.5),
#  (44, 50, 1, 1, 1, 127.0, 0.0),
#  (44, 51, 1, 1, 1, 132.0, 0.0),
#  (45, 50, 1, 1, 1, 114.0, 0.0),
#  (45, 51, 1, 1, 1, 109.0, 0.0),
#  (46, 48, 2, 2, 4, 97.0, 16.5),
#  (46, 50, 2, 2, 4, 84.25, 42.1875),
#  (44, 52, 0, 0, 0, nan, nan),
#  (44, 52, 0, 0, 0, nan, nan),
#  (44, 52, 0, 0, 0, nan, nan),
#  (44, 52, 0, 0, 0, nan, nan),
#  (44, 53, 1, 1, 1, 122.0, 0.0),
#  (45, 52, 1, 1, 1, 104.0, 0.0),
#  (45, 53, 1, 1, 1, 97.0, 0.0),
#  (44, 54, 2, 2, 4, 107.75, 20.1875),
#  (46, 52, 2, 2, 4, 74.75, 7.1875),
#  (46, 54, 1, 1, 1, 85.0, 0.0),
#  (46, 55, 1, 1, 1, 105.0, 0.0),
#  (47, 54, 1, 1, 1, 84.0, 0.0),
#  (47, 55, 1, 1, 1, 106.0, 0.0),
#  (49, 32, 0, 0, 0, nan, nan),
#  (49, 32, 0, 0, 0, nan, nan),
#  (49, 33, 1, 1, 1, 106.0, 0.0),
#  (48, 34, 2, 2, 4, 112.75, 33.6875),
#  (50, 32, 2, 2, 4, 79.5, 113.25),
#  (50, 34, 2, 2, 4, 96.75, 36.6875),
#  (48, 36, 4, 4, 16, 76.375, 160.359375),
#  (52, 32, 4, 4, 16, 64.75, 69.4375),
#  (52, 36, 2, 2, 4, 64.0, 8.5),
#  (52, 38, 1, 1, 1, 62.0, 0.0),
#  (52, 39, 1, 1, 1, 71.0, 0.0),
#  (53, 38, 1, 1, 1, 69.0, 0.0),
#  (53, 39, 1, 1, 1, 82.0, 0.0),
#  (54, 36, 1, 1, 1, 55.0, 0.0),
#  (54, 37, 1, 1, 1, 62.0, 0.0),
#  (55, 36, 1, 1, 1, 56.0, 0.0),
#  (55, 37, 1, 1, 1, 68.0, 0.0),
#  (54, 38, 2, 2, 4, 87.25, 63.1875),
#  (48, 40, 4, 4, 16, 86.9375, 116.05859375),
#  (48, 44, 4, 4, 16, 106.25, 100.4375),
#  (52, 40, 4, 4, 16, 99.5, 95.75),
#  (52, 44, 4, 4, 16, 115.625, 93.484375),
#  (56, 32, 2, 2, 4, 81.5, 12.75),
#  (56, 34, 1, 1, 1, 68.0, 0.0),
#  (56, 35, 1, 1, 1, 59.0, 0.0),
#  (57, 34, 1, 1, 1, 82.0, 0.0),
#  (57, 35, 1, 1, 1, 73.0, 0.0),
#  (58, 32, 1, 1, 1, 68.0, 0.0),
#  (58, 33, 1, 1, 1, 84.0, 0.0),
#  (59, 32, 1, 1, 1, 57.0, 0.0),
#  (59, 33, 0, 0, 0, nan, nan),
#  (59, 33, 0, 0, 0, nan, nan),
#  (59, 33, 0, 0, 0, nan, nan),
#  (59, 33, 0, 0, 0, nan, nan),
#  (58, 34, 1, 1, 1, 97.0, 0.0),
#  (58, 35, 0, 0, 0, nan, nan),
#  (58, 35, 0, 0, 0, nan, nan),
#  (58, 35, 0, 0, 0, nan, nan),
#  (58, 35, 0, 0, 0, nan, nan),
#  (59, 34, 1, 1, 1, 103.0, 0.0),
#  (59, 35, 1, 1, 1, 119.0, 0.0),
#  (56, 36, 1, 1, 1, 58.0, 0.0),
#  (56, 37, 1, 1, 1, 77.0, 0.0),
#  ...]

# %% [markdown]
# ### Question 2
# In the remainder, the formal type is considered:
# ```python
# type Region = list[BlocStats]
# ```
# A region, as seen during the tutorial work, is therefore a list of blocks. Write the predicate ``predmerge(b,R,*args)`` as seen in tutorial work. This function returns ``True`` if the ``b`` block should merge into the ``R`` region. If a merge happens, then the first item of ``R`` will have its statistics updated to describe the statistics of the region ``R`` merged with `b`.

# %%
def predmerge(b,R,*args):
    """ BlocsStat*Region*... -> bool 
        If merge, R[0] is modified
    """
    c = R[0]
    n1,n2 = c[4],b[4]
    mu1,mu2 = c[5],b[5]
    var1,var2 = c[6],b[6]
    
    mu12,mu22 = mu1**2,mu2**2
    n = n1+n2
    mu = (n1*mu1 + n2*mu2)/n
    mu2 = mu**2

    var = (n1*(var1+mu12) + n2*(var2+mu22))/n - mu2

    if var <= args[0]:
        R[0] = c[0],c[1],c[2],c[3],n,mu,var
        return True
    
    return False

# %% [markdown]
# ### Question 3
# Using `predmerge()` and `neighbors()` functions, given at the beginning of the notebook, write the function ``merge()`` discussed in tutorial work (exercise 7.6).
#
# Recalls on Python lists:
# - Remove an element `a` from a list `L`: `L.remove(a)`
# - Test if `a` belongs to a list `L`: `a in L`
# - Iterate the elements of a list `L`: `for a in L:`
# - Access to an element of a list: as with numpy arrays

# %%
def merge(S,I,pred,*args):
    """ QuadTree*Array*(BlockStat*Region*...->bool) -> list[Region]
        Merge the leaves of S in a list of regions
    """
    K = listRegionsStat(S,I)
    L = []
    while len(K) > 0:
        b = K[0]
        R = [b]
        K = K[1:]
        N = neighbors(b,K)
        while len(N)>0:
            bn = N[0]
            N = N[1:]
            if pred(bn,R,args[0]):
                K.remove(bn)
                R.append(bn)
                N_bn = neighbors(bn,K)
                for q in N_bn:
                    if q not in N:
                        N.append(q) # voisins qui ne sont pas déjà dans N
        #
        L.append(R)
    #
    return L

# %% [markdown]
# ### Question 4
# Test the previous functions using the synthetic image `img_test`. In particular, check that merge() returns a list of 3 elements (i.e. 3 regions).

# %%
QT = split(img_test,(0,0,img_test.shape[0],img_test.shape[1]),predsplit,0)
M = merge(QT,img_test,predmerge, 0)
print(len(M))
assert len(M) == 3
print("  ",M[0][0],"\n  ",M[1][0],"\n  ",M[2][0])
# Out:
# 3
#    (0, 0, 16, 16, 3328, 0.0, 0.0)
#    (8, 40, 8, 8, 256, 150.0, 0.0)
#    (32, 16, 8, 8, 512, 100.0, 0.0)

# %% [markdown]
# ### Question 5
# Write a function ``regions(LR,shape)`` that takes as arguments a list of regions (such as returned by the function ``merge()``) and an image size, and returns an image of the regions. Each region will be colored with the gray level corresponding to the average of the region. The ``shape`` parameter gives the size of the image to be produced.
#
# Test the function on the previous example.

# %%
def regions(LR,shape):
    """ list[Region]*tuple[int,int] -> Array """
    I = np.zeros(shape)
    for R in LR:
        for qt in R:
            x,y,n,m,s,mu,v = qt
            for i in range(n):
                for j in range(m):
                    I[x+i,y+j] = R[0][5]
    
    return I

# %%
Ir = regions(M,img_test.shape)
plt.imshow(Ir)

# %% [markdown]
# ## Exercise 4: experiments
# ### Question 1
# Test the function ``merge()`` on the images ``angio``, ``cam``, ``muscle``, ``prisme`` and ``seiche``. Try to produce the best segmentations.

# %%
I = angio
sig = np.std(I.reshape(I.size))
QT = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.2*sig)
M = merge(QT,I,predmerge, 0.2*sig)
Ir = regions(M,I.shape)
plt.imshow(I)
plt.show()
plt.imshow(Ir)
plt.show()

QT = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.4*sig)
M = merge(QT,I,predmerge, 0.4*sig)
Ir = regions(M,I.shape)
plt.imshow(Ir)
plt.show()

QT = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.6*sig)
M = merge(QT,I,predmerge, 0.6*sig)
Ir = regions(M,I.shape)
plt.imshow(Ir)
plt.show()

# %%
I = cam
sig = np.std(I.reshape(I.size))
QT = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.1*sig)
M = merge(QT,I,predmerge, 0.1*sig)
Ir = regions(M,I.shape)
plt.imshow(I)
plt.show()
plt.imshow(Ir)
plt.show()

QT = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.4*sig)
M = merge(QT,I,predmerge, 0.4*sig)
Ir = regions(M,I.shape)
plt.imshow(Ir)
plt.show()

QT = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.6*sig)
M = merge(QT,I,predmerge, 0.6*sig)
Ir = regions(M,I.shape)
plt.imshow(Ir)
plt.show()

# %%
I = muscle
sig = np.std(I.reshape(I.size))
QT = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.1*sig)
M = merge(QT,I,predmerge, 0.1*sig)
Ir = regions(M,I.shape)
plt.imshow(I)
plt.show()
plt.imshow(Ir)
plt.show()

QT = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.2*sig)
M = merge(QT,I,predmerge, 0.2*sig)
Ir = regions(M,I.shape)
plt.imshow(Ir)
plt.show()

QT = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.4*sig)
M = merge(QT,I,predmerge, 0.4*sig)
Ir = regions(M,I.shape)
plt.imshow(Ir)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/x7/bmqxr1zd3lxd_kcxxw9physr0000gn/T/ipykernel_22165/4091938983.py in <module>
#      16
#      17 QT = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.4*sig)
# ---> 18 M = merge(QT,I,predmerge, 0)
#      19 Ir = regions(M,I.shape)
#      20 plt.imshow(Ir)
#
# /var/folders/x7/bmqxr1zd3lxd_kcxxw9physr0000gn/T/ipykernel_22165/3051438438.py in merge(S, I, pred, *args)
#      16                 K.remove(bn)
#      17                 R.append(bn)
# ---> 18                 N_bn = neighbors(bn,K)
#      19                 for q in N_bn:
#      20                     if q not in N:
#
# /var/folders/x7/bmqxr1zd3lxd_kcxxw9physr0000gn/T/ipykernel_22165/1030357789.py in neighbors(b, K)
#      34     N = []
#      35     for n in K:
# ---> 36         if areNeighbors(b,n):
#      37             N.append(n)
#      38     return N
#
# /var/folders/x7/bmqxr1zd3lxd_kcxxw9physr0000gn/T/ipykernel_22165/1030357789.py in areNeighbors(a, b)
#      31             a,b=b,a
#      32         x,y = a[0]+a[2]//2,a[1]+a[3]//2
# ---> 33         return belongsTo(x+a[2],y,b) or belongsTo(x-a[2],y,b) or belongsTo(x,y+a[3],b) or belongsTo(x,y-a[3],b)
#      34     N = []
#      35     for n in K:
#
# /var/folders/x7/bmqxr1zd3lxd_kcxxw9physr0000gn/T/ipykernel_22165/1030357789.py in belongsTo(x, y, a)
#      19         returns the list of neighbors of b and elements of K
#      20     """
# ---> 21     def belongsTo(x,y,a):
#      22         """ int*int*BlockStat -> bool
#      23             Test if pixel (x,y) belongs to block a
#
# KeyboardInterrupt:

# %%
I = prisme
sig = np.std(I.reshape(I.size))
QT = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.1*sig)
M = merge(QT,I,predmerge, 0.1*sig)
Ir = regions(M,I.shape)
plt.imshow(I)
plt.show()
plt.imshow(Ir)
plt.show()

QT = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.4*sig)
M = merge(QT,I,predmerge, 0.4*sig)
Ir = regions(M,I.shape)
plt.imshow(Ir)
plt.show()

QT = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.6*sig)
M = merge(QT,I,predmerge, 0.6*sig)
Ir = regions(M,I.shape)
plt.imshow(Ir)
plt.show()

# %%
I = seiche
sig = np.std(I.reshape(I.size))
QT = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.1*sig)
M = merge(QT,I,predmerge, 0.1*sig)
Ir = regions(M,I.shape)
plt.imshow(I)
plt.show()
plt.imshow(Ir)
plt.show()

QT = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.4*sig)
M = merge(QT,I,predmerge, 0.4*sig)
Ir = regions(M,I.shape)
plt.imshow(Ir)
plt.show()

QT = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.6*sig)
M = merge(QT,I,predmerge, 0.6*sig)
Ir = regions(M,I.shape)
plt.imshow(Ir)
plt.show()

# %% [markdown]
# ### Question 2
# The result of the merge algorithm highly depends on how you visit the regions. One can then sort the leaves of the quadtree, for example, from the smallest to the largest blocks, or the opposite (use the Python function ``sorted()``).
# The same question arises when calculating the set of neighbors of the merged region. Should they be sorted? If yes, according to which criteria? their size? their proximity?
# Obviously there is no universal answer but it should be adapted to each type of problem.
# Do some tests to see the influence of these sortings on the result of the merger.

# %%
def large_block(QT):
  return QT[4]

# %%
def merge(S,I,pred,*args):
    """ QuadTree*Array*(BlockStat*Region*...->bool) -> list[Region]
        Merge the leaves of S in a list of regions
    """
    K = listRegionsStat(S,I)
    if len(args) > 1: # fonction de tri
      r = False
      if len(args) > 2:
        r = args[2] # croissant ou décroissant
      K = sorted(K,key=args[1],reverse=r)
    L = []
    while len(K) > 0:
        b = K[0]
        R = [b]
        K = K[1:]
        N = neighbors(b,K)
        while len(N)>0:
            bn = N[0]
            N = N[1:]
            if pred(bn,R,args[0]):
                K.remove(bn)
                R.append(bn)
                N_bn = neighbors(bn,K)
                for q in N_bn:
                    if q not in N:
                        N.append(q) # voisins qui ne sont pas déjà dans N
        #
        L.append(R)
    #
    return L

# %%
I = angio
sig = np.std(I.reshape(I.size))
QT = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.2*sig)

# ascendant
M = merge(QT,I,predmerge, 0.2*sig,large_block)
Ir = regions(M,I.shape)
plt.imshow(I)
plt.show()
plt.imshow(Ir)
plt.show()

# descendant
M = merge(QT,I,predmerge, 0.2*sig,large_block,True)
Ir = regions(M,I.shape)
plt.imshow(Ir)
plt.show()

# %%
I = prisme
sig = np.std(I.reshape(I.size))
QT = split(I,(0,0,I.shape[0],I.shape[1]),predsplit,0.1*sig)

# ascendant
M = merge(QT,I,predmerge, 0.1*sig,large_block)
Ir = regions(M,I.shape)
plt.imshow(I)
plt.show()
plt.imshow(Ir)
plt.show()

# descendant
M = merge(QT,I,predmerge, 0.1*sig,large_block,True)
Ir = regions(M,I.shape)
plt.imshow(Ir)
plt.show()

# %% [markdown]
# ### Question 3 (bonus)
# Imagine and experiment alternative predicates for both the split and the merge steps. It is possible to use edges-based predicates, and also to combine with variance-based predicates.
